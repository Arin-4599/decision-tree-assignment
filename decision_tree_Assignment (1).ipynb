# %% [markdown]
# # DECISION TREE ASSIGNMENT
#
# 1. What is a Decision Tree, and how does it work?
#    - they are looks like a tree they work on nested if-else condition
#    - they contain leaf node root node and internal node
#
# 2. What are impurity measures in Decision Trees?
#    - classification, Gini, Entropy are the impurity measure in decision tree
#
# 3. What is the mathematical formula for Gini Impurity?
#    - formulae :- 1- summitation(i=0) to n-1 (pi) **2
#
# 4. What is the mathematical formula for Entropy?
#    - fromulae :-  -summation (i=0) to (i=n-1) pi*log*pi
#
# 5. What is Information Gain, and how is it used in Decision Trees?
#    - information gain is called (change in impurity)
#    - it is measure to define the degree of disorganisation
#
# 6. What is the difference between Gini Impurity and Entropy?
#    - these both are mostly used in industry
#    - range of entropy = 0 to 1
#    - range of gini = 0 to 0.5
#
# 7. What is the mathematical explanation behind Decision Trees?
#    - it is used to split the data by given information
#    - those have maxinmum information gain used fro spliting
#
# 8. What is Pre-Pruning in Decision Trees?
#    -  this is used to reduce overfitting
#    -  pre-pruning is used to limit the growth of decision tree
#
# 9. What is Post-Pruning in Decision Trees?
#    - constructed the entire decision tree till leaf node
#    - prune the decision tree
#    - it should be used for only small datasets
#
# 10. What is the difference between Pre-Pruning and Post-Pruning?
#     -  this is used to reduce overfitting
#       pre-pruning is used to limit the growth of decision tree
#     - post pruning =  constructed the entire decision tree till leaf node ,
#         prune the decision tree,
#         it should be used for only small datasets
#
# 11. What is a Decision Tree Regressor?
#     - dt regression has varance and variance reacihann
#     - finial aim is to various reduction
#     - you will split whichever feature gives the highest feature reduction
#
# 12. What are the advantages and disadvantages of Decision Trees?
#     - simple to understand
#     - capture nin-linear relationship
#     - dt divides the data into nodes    these are advantage
#     - disadvantage = high time complexity
#
# 13. How does a Decision Tree handle missing values?
#     - Ignoring Instances with Missing Values,  Imputation Before Tree Construction these are some ways to handel the missing values in dt
#
# 14. How does a Decision Tree handle categorical features?
#     - Decision Trees naturally handle categorical features well, though the exact method depends on the implementation and whether the categories are ordinal or nominal
#
# 15. What are some real-world applications of Decision Trees?
#     - healthcare and banking finance etc are real world application of decision tree

# %%
# 16. Write a Python program to train a Decision Tree Classifier on the Iris dataset and print the model accuracy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
data = load_iris()
print(data.DESCR)

df = pd.DataFrame(data.data, columns = data.feature_names)
df

data.target

x= df
y = data.target
x, y

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion= 'entropy')
classifier

classifier.fit(x_train, y_train)

from sklearn import tree
plt.figure(figsize= (12, 10))
tree.plot_tree(classifier, filled = True)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...
